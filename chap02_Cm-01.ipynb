# %% [markdown]
# <a href="https://colab.research.google.com/github/hondaki/TU_M_Math_2026/blob/main/chap02_Cm-01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
print( np.sqrt(2.0) )
b=np.float32(2)
type(b)
print(b.dtype)
# Out:
# 1.4142135623730951
# float32

# %%
'''
a=3.5
print( np.sqrt(a))
b=np.float32(2)
type(a)
type(b)
# print(b.dtype)
# %precision 3
a= np.array([[5,2,3],[103,4,8]])
a.dtype
a.ndim
a[1]
a*2
# print( a.sort() )
print( a[1:] )
a=np.arange(9,18).reshape(3,3)
a.T
'''
